# %%
DFG
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-1d34b9d74909> in <module>()
# ----> 1 DFG
#
# NameError: name 'DFG' is not defined

# %% [markdown]
# # Hyderavad
# ## Hyd
# ### hyd
# #### hyd
# ###### hyd
# ###### hyd

# %% [markdown]
# > this is

# %% [markdown]
# `hi this`

# %% [markdown]
# ---------------
# njmghkm
# hvvyjg
#
# jgjn
#
# ---------------
#
# kguhk,

# %% [markdown]
# **jihkk**

# %% [markdown]
# *jkh *
#
# - jhkiu

# %% [markdown]
# - point 1
# 1. point 1

# %% [markdown]
# [link](https://hydblooddonors.org/)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# [message_to_display]("www.google.com")

# %% [markdown]
# [message_to_display](https://hydblooddonors.org/)

# %% [markdown]
# <img src="https://content.r9cdn.net/rimg/dimg/e3/36/d71f2b55-city-7297-16494c3d70c.jpg?width=1366&height=768&xhint=3186&yhint=1580&crop=true">
